# %% [markdown]
# ## Run PII detection on the dataset

# %% [markdown]
# ### 1. Use Regexes for all the PII types

# %%
from datasets import load_dataset

from pii_detection import scan_pii_batch

#from utils.evaluation import evaluate_pii, evaluate_pii_ds, recall_precision
#from utils.jia_evaluation import evaluate_pii, evaluate_pii_ds, recall_precision
from utils.eval_space import evaluate_pii, evaluate_pii_ds, recall_precision

ds = load_dataset("bigcode/pii-for-code", use_auth_token=True)["train"]
# Out:
# Using custom data configuration bigcode--pii-for-code-2f55abc831915fa6
# Found cached dataset json (/Users/loubnabenallal/.cache/huggingface/datasets/bigcode___json/bigcode--pii-for-code-2f55abc831915fa6/0.0.0/e6070c77f18f01a5ad4551a8b7edfba20b8438b7cad4d94e6ad9378022ce4aab)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ds
# Out:
# Dataset({
#     features: ['content', 'language', 'license', 'path', 'annotation_id', 'pii', 'pii_modified', 'id'],
#     num_rows: 400
# })

# %%
examples = ds.select(range(400))
ds_pii_2 = examples.map(lambda x: scan_pii_batch(x, key_detector="other"), batched=True, batch_size=10, load_from_cache_file=False)
# Out:
#   0%|          | 0/40 [00:00<?, ?ba/s]

# %%
# evaluate on the whole 100 samples
metrics_2, metrics_dict_2, details_2 = evaluate_pii_ds(ds_pii_2, pred_column='secrets', ref_column="pii_modified", overall_score=False, alpha=0.8, beta=0.8, return_details=True)

# %%
metrics_2
# Out:
# {'EMAIL': {'recall': 0.9585492227979274, 'precision': 0.8767772511848341},
#  'IP_ADDRESS': {'recall': 0.8282828282828283, 'precision': 0.803921568627451},
#  'KEY': {'recall': 0.5294117647058824, 'precision': 0.782608695652174}}

# %%
metrics_dict_2
# Out:
# {'EMAIL': {'TP': 185, 'FN': 8, 'FP': 26},
#  'IP_ADDRESS': {'TP': 82, 'FN': 17, 'FP': 20},
#  'KEY': {'TP': 18, 'FN': 16, 'FP': 5}}

# %% [markdown]
# The following data is used to build a vizualization space

# %%
#let's just get emails
email_detections = {"FN": [], "FP": []}
TAGS = ["EMAIL", "KEY", "IP_ADDRESS"]

def get_fn(data, tag):
    detections = []
    for i in range(len(data)):
        details = data[i]["details"][tag]
        if not details["FN"]:
            continue
        # sort elements inside FN by start index
        details["FN"] = sorted(details["FN"], key=lambda x: x["start"])
        print(f"not skipped {i}")
        # add content to each detection while hightlighting detected words
        subparts = []
        advance = 0
        for detection in details["FN"]:
            if detection["value"] == "discoiquuid":
                print("wrong label found")
                continue
            text = details["content"][advance:detection["start"]] 
            subpart = text if text else " "
            subparts.append(subpart)
            subparts.append("PI:FN:" + details["content"][detection["start"]:detection["end"]] + "END_PI")
            print(tag, "PI:FN:" + details["content"][detection["start"]:detection["end"]] + "END_PI")
            last_part = details["content"][detection["end"]:]
            advance = detection["end"]
        displayed_text = "".join(subparts) + last_part
        detections.append(displayed_text)
    return detections

def get_fp(data, tag):
    detections = []
    for i in range(len(data)):
        details = data[i]["details"][tag]
        if not details["FP"]:
            continue
        # sort elements inside FP by start index
        details["FP"] = sorted(details["FP"], key=lambda x: x["start"])
        print(f"not skipped {i}")
        # add content to each detection while hightlighting detected words
        subparts = []
        advance = 0
        for detection in details["FP"]:
            if detection["value"] == "discoiquuid":
                print("wrong label found")
                continue
            text = details["content"][advance:detection["start"]] 
            subpart = text if text else " "
            print(f"length of subpart: {len(subpart)}")
            subparts.append(subpart)
            subparts.append("PI:FP:" + details["content"][detection["start"]:detection["end"]] + "END_PI")
            print(tag, "PI:FP:" + details["content"][detection["start"]:detection["end"]] + "END_PI")
            last_part = details["content"][detection["end"]:]
            print(f"length of last part: {len(last_part)}")
            advance = detection["end"]
        displayed_text = "".join(subparts) + last_part
        detections.append(displayed_text)
    return detections

print("email FN")
email_detections_fn = get_fn(details_2, "EMAIL")
print("email FP")
email_detections_fp = get_fp(details_2, "EMAIL")

print("key FN")
key_detections_fn = get_fn(details_2, "KEY")
print("key FP")
key_detections_fp = get_fp(details_2, "KEY")

print("ip FN")
ip_detections_fn = get_fn(details_2, "IP_ADDRESS")
print("ip FP")
ip_detections_fp = get_fp(details_2, "IP_ADDRESS")

# %%
# save list in json file
import json
with open("data/email_detections_fn.json", "w") as f:
    json.dump(email_detections_fn, f)

with open("data/email_detections_fp.json", "w") as f:
    json.dump(email_detections_fp, f)

with open("data/key_detections_fn.json", "w") as f:
    json.dump(key_detections_fn, f)

with open("data/key_detections_fp.json", "w") as f:
    json.dump(key_detections_fp, f)

with open("data/ip_address_detections_fn.json", "w") as f:
    json.dump(ip_detections_fn, f)

with open("data/ip_address_detections_fp.json", "w") as f:
    json.dump(ip_detections_fp, f)

# %%
# plot number TP, FP, FN for each tag
# use ggplot style
plt.style.use('ggplot')
tags = ["EMAIL", "IP_ADDRESS", "KEY"]
values = [metrics_dict_2[tag] for tag in tags]
tp = [v["TP"] for v in values]
fp = [v["FP"] for v in values]
fn = [v["FN"] for v in values]
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(len(tags))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots()
# use mat
# use green, dark orange and royal blue and bars shouldn't overlap
rects1 = ax.bar(x - width, tp, width, label='TP', color="#228B22")
rects2 = ax.bar(x, fp, width, label='FP', color="#4169E1")
rects3 = ax.bar(x + width, fn, width, label='FN', color="#FF8C00")

# Add some text for labels, title and custom x-axis tick labels, etc.
# use Mathematica text in title and increase size
ax.set_title('Number of TP, FP, FN samples for each tag', fontname="STIXGeneral", fontsize=16)

ax.set_xticks(x)
ax.set_xticklabels(tags)
ax.legend()

fig.tight_layout()

plt.show()

# %%
details_2
# Out:
# [{'id': 0,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'davis@dlib.net',
#       'start': 38,
#       'end': 52}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'davis@dlib.net',
#       'start': 38,
#       'end': 52,
#       'context': '// Copyright (C) 2003  Davis E. King (davis@dlib.net), Miguel Grinberg\n// License: Boost Software Lice'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 1,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 2,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'intersight@cisco.com',
#       'start': 1797,
#       'end': 1817}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'intersight@cisco.com',
#       'start': 1797,
#       'end': 1817,
#       'context': 'sion of the OpenAPI document: 1.0.9-4870\nContact: intersight@cisco.com\nGenerated by: https://openapi-generator.tech\nOpen'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 3,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'nugetvss@microsoft.com',
#       'start': 421,
#       'end': 443}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'nugetvss@microsoft.com',
#       'start': 421,
#       'end': 443,
#       'context': '\n * OpenAPI spec version: 4.1-preview\n * Contact: nugetvss@microsoft.com\n * Generated by: https://github.com/swagger-api/s'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 4,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 5,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'info@srampos.com',
#       'start': 195,
#       'end': 211}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'info@srampos.com',
#       'start': 195,
#       'end': 211,
#       'context': '===========\n *  Author    : Sheik\n *  Email     : info@srampos.com\n *  For       : SRAM POS\n *  Web       : http://s'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 6,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 7,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'liu21st@gmail.com',
#       'start': 503,
#       'end': 520}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'liu21st@gmail.com',
#       'start': 503,
#       'end': 520,
#       'context': '---------------------------\n// | Author: liu21st <liu21st@gmail.com>\n// +--------------------------------------------'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 8,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 9,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'beat-kueng@gmx.net',
#       'start': 1820,
#       'end': 1838}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'beat-kueng@gmx.net',
#       'start': 1820,
#       'end': 1838,
#       'context': 'or Leon Müller (thedevleon)\n * @author Beat Küng <beat-kueng@gmx.net>\n * MAV_MOUNT driver for controlling mavlink gimb'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 10,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'porten@kde.org',
#       'start': 606,
#       'end': 620},
#      {'tag': 'EMAIL', 'value': 'pmk@post.com', 'start': 658, 'end': 670},
#      {'tag': 'EMAIL',
#       'value': 'cwzwarich@uwaterloo.ca',
#       'start': 803,
#       'end': 825}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'cwzwarich@uwaterloo.ca',
#       'start': 803,
#       'end': 825,
#       'context': 'reserved.\n *  Copyright (C) 2007 Cameron Zwarich (cwzwarich@uwaterloo.ca)\n *  Copyright (C) 2007 Maks Orlovich\n *\n *  This'},
#      {'tag': 'EMAIL',
#       'value': 'porten@kde.org',
#       'start': 606,
#       'end': 620,
#       'context': '\n\n*/\n/*\n *  Copyright (C) 1999-2002 Harri Porten (porten@kde.org)\n *  Copyright (C) 2001 Peter Kelly (pmk@post.com'},
#      {'tag': 'EMAIL',
#       'value': 'pmk@post.com',
#       'start': 658,
#       'end': 670,
#       'context': 'rten@kde.org)\n *  Copyright (C) 2001 Peter Kelly (pmk@post.com)\n *  Copyright (C) 2003, 2004, 2005, 2006, 2007, '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 11,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 12,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'kohsuke.kawaguchi@sun.com',
#       'start': 1766,
#       'end': 1791}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'kohsuke.kawaguchi@sun.com',
#       'start': 1766,
#       'end': 1791,
#       'context': ' result.\n *\n * @author\n *      Kohsuke Kawaguchi (kohsuke.kawaguchi@sun.com)\n */\npublic class SingleStreamCodeWriter extends '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 13,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'will@thames.id.au',
#       'start': 62,
#       'end': 79}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'will@thames.id.au',
#       'start': 62,
#       'end': 79,
#       'context': 'nv python\n\n# Copyright (c) 2013-2014 Will Thames <will@thames.id.au>\n#\n# Permission is hereby granted, free of charge'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 14,
#   'details': {'EMAIL': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [{'tag': 'EMAIL',
#       'value': 'benyuwan@gmail.com',
#       'start': 16,
#       'end': 34,
#       'context': "/**\n * @author {benyuwan@gmail.com}\n * @file tags的model\n */\n\nimport query from '../u"}],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 15,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'andreas@wellenvogel.net',
#       'start': 172,
#       'end': 195}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'andreas@wellenvogel.net',
#       'start': 172,
#       'end': 195,
#       'context': '####\n# Copyright (c) 2012,2013-2021 Andreas Vogel andreas@wellenvogel.net\n#\n#  Permission is hereby granted, free of charge'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 16,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '72.44.36.12',
#       'start': 1193,
#       'end': 1204},
#      {'tag': 'IP_ADDRESS', 'value': '72.44.36.12', 'start': 1289, 'end': 1300},
#      {'tag': 'IP_ADDRESS',
#       'value': '72.44.36.12',
#       'start': 1336,
#       'end': 1347}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '72.44.36.12',
#       'start': 1336,
#       'end': 1347,
#       'context': '  "72.44.36.12".convert_from_ec2_to_ip.should == "72.44.36.12"\n    end\n    it "should be able to parse the date'},
#      {'tag': 'IP_ADDRESS',
#       'value': '72.44.36.12',
#       'start': 1289,
#       'end': 1300,
#       'context': 'an error if another string is returned" do\n      "72.44.36.12".convert_from_ec2_to_ip.should == "72.44.36.12"\n '},
#      {'tag': 'IP_ADDRESS',
#       'value': '72.44.36.12',
#       'start': 1193,
#       'end': 1204}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 17,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'test.satou@example.com',
#       'start': 1338,
#       'end': 1360}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'test.satou@example.com',
#       'start': 1338,
#       'end': 1360,
#       'context': 'il",\n    autoComplete: "email",\n    placeholder: "test.satou@example.com",\n  },\n  // {\n  //   id: "businessProfileMcc",\n  '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 18,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 19,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 20,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 21,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'nicolas.george@normalesup.org',
#       'start': 41,
#       'end': 70}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'nicolas.george@normalesup.org',
#       'start': 41,
#       'end': 70,
#       'context': '/*\n * Copyright (C) 2009 Nicolas George <nicolas.george@normalesup.org>\n *\n * This file is part of MPlayer.\n *\n * MPlaye'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 22,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '255.255.255.255',
#       'start': 2035,
#       'end': 2050},
#      {'tag': 'IP_ADDRESS',
#       'value': '255.255.255.0',
#       'start': 5059,
#       'end': 5072}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '255.255.255.0',
#       'start': 5059,
#       'end': 5072,
#       'context': "address]).get_mask :\n                            '255.255.255.0',\n              dhcp_enabled: true,\n             "},
#      {'tag': 'IP_ADDRESS',
#       'value': '255.255.255.255',
#       'start': 2035,
#       'end': 2050,
#       'context': "*)\\/(.*)>/\n\n          if Regexp.last_match(2) == '255.255.255.255'\n            raise Errors::ManagementNetworkError"}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 23,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'user@test.com',
#       'start': 797,
#       'end': 810},
#      {'tag': 'EMAIL', 'value': 'user@test.com', 'start': 936, 'end': 949},
#      {'tag': 'EMAIL', 'value': 'user1@test.com', 'start': 1086, 'end': 1100},
#      {'tag': 'EMAIL', 'value': 'user1@test.com', 'start': 1240, 'end': 1254}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'user1@test.com',
#       'start': 1086,
#       'end': 1100,
#       'context': '         username="someuser1",\n            email="user1@test.com",\n            password="secret_password1",\n      '},
#      {'tag': 'EMAIL',
#       'value': 'user@test.com',
#       'start': 936,
#       'end': 949,
#       'context': 'bjects.create(\n            user=self.user, email="user@test.com", primary=True, verified=True\n        )\n\n        '},
#      {'tag': 'EMAIL',
#       'value': 'user@test.com',
#       'start': 797,
#       'end': 810,
#       'context': '          username="someuser",\n            email="user@test.com",\n            password="secret_password",\n       '},
#      {'tag': 'EMAIL',
#       'value': 'user1@test.com',
#       'start': 1240,
#       'end': 1254,
#       'context': '(\n            user=self.user1,\n            email="user1@test.com",\n            primary=True,\n            verified='}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 24,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 25,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'jfinal@126.com',
#       'start': 48,
#       'end': 62}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'jfinal@126.com',
#       'start': 48,
#       'end': 62,
#       'context': '/**\r\n * Copyright (c) 2011-2021, James Zhan 詹波 (jfinal@126.com).\r\n *\r\n * Licensed under the Apache License, Vers'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 26,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [{'tag': 'KEY',
#       'value': '306071f9db7b2ab1e92edc63a77973c7',
#       'start': 1464,
#       'end': 1496,
#       'context': 'returns true, else returns false.\n */\n@Generated("306071f9db7b2ab1e92edc63a77973c7")\npublic final class MapIsLockedCodec {\n    //hex'}],
#     'FP': []}}},
#  {'id': 27,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '162.243.201.175',
#       'start': 571,
#       'end': 586}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '162.243.201.175',
#       'start': 571,
#       'end': 586,
#       'context': "entWSID = 'localSealogReceive'\n\nremoteServerIP = '162.243.201.175'\nremoteServerAPIPort = '80'\nremoteServerWSPort = "}],
#     'FN': [{'tag': 'IP_ADDRESS',
#       'value': '0.0.0.0',
#       'start': 163,
#       'end': 170,
#       'context': "ventsAPIPath = '/api/v1/events'\n\nlocalServerIP = '0.0.0.0'\nlocalServerAPIPort = '8000'\nlocalServerWSPort = "}],
#     'FP': []},
#    'KEY': {'TP_pred': [{'tag': 'KEY',
#       'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ.',
#       'start': 276,
#       'end': 468},
#      {'tag': 'KEY',
#       'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ.',
#       'start': 694,
#       'end': 886}],
#     'TP_ref': [{'tag': 'KEY',
#       'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ.D8ja66bnLxJ3bsJlaKRtOquu8XbibjNCyFxJpI7vafc',
#       'start': 276,
#       'end': 511,
#       'context': "\nlocalServerPath = '/sealog-server'\nlocalToken = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDE0NDE3fQ.D8ja66bnLxJ3bsJlaKRtOquu8XbibjNCyFxJpI7vafc'\nlocalClientWSID = 'localSealogReceive'\n\nremoteSe"},
#      {'tag': 'KEY',
#       'value': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ.8X-fBRUHdrwtkTLcOFAsW-vvvqCzmkZKM2gQgHNkBKk',
#       'start': 694,
#       'end': 929,
#       'context': 'emoteServerPath = \'/sealog-server\'\nremoteToken = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjU5ODFmMTY3MjEyYjM0OGFlZDdmYTlmNSIsInNjb3BlIjpbImFkbWluIiwiZXZlbnRfbWFuYWdlciIsImV2ZW50X2xvZ2dlciIsImV2ZW50X3dhdGNoZXIiXSwiaWF0IjoxNTI1MDEzNTUxfQ.8X-fBRUHdrwtkTLcOFAsW-vvvqCzmkZKM2gQgHNkBKk"\nremoteClientWSID = \'remoteSealogReceive\'\n\nhello '}],
#     'FN': [],
#     'FP': []}}},
#  {'id': 28,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 29,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'david@reciprocitylabs.com',
#       'start': 172,
#       'end': 197},
#      {'tag': 'EMAIL',
#       'value': 'david@reciprocitylabs.com',
#       'start': 215,
#       'end': 240}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'david@reciprocitylabs.com',
#       'start': 172,
#       'end': 197,
#       'context': 'nses/LICENSE-2.0 <see LICENSE file>\n# Created By: david@reciprocitylabs.com\n# Maintained By: david@reciprocitylabs.com\n\nimpor'},
#      {'tag': 'EMAIL',
#       'value': 'david@reciprocitylabs.com',
#       'start': 215,
#       'end': 240,
#       'context': 'ed By: david@reciprocitylabs.com\n# Maintained By: david@reciprocitylabs.com\n\nimport re\nfrom sqlalchemy.orm import validates\n\n'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 30,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'f.miir117@gmail.com',
#       'start': 30,
#       'end': 49}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'f.miir117@gmail.com',
#       'start': 30,
#       'end': 49,
#       'context': '/*\n * Muhammad Faisal Amir\n * f.miir117@gmail.com\n * id.amirisback.bandung\n * Copyright 2017\n */\npa'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 31,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 32,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 33,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 34,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [{'tag': 'KEY',
#       'value': 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN0123456789',
#       'start': 719,
#       'end': 769},
#      {'tag': 'KEY',
#       'value': 'ABCDEFGHIJKLMNabcdefghijklmnopqrstuvwxyz0123456789',
#       'start': 795,
#       'end': 845}],
#     'TP_ref': [{'tag': 'KEY',
#       'value': 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN0123456789',
#       'start': 719,
#       'end': 769,
#       'context': '"0123456789abcdefghijklmno",\n      apiKeySecret: "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN0123456789",\n      accessTokenKey: "ABCDEFGHIJKLMNabcdefghij'},
#      {'tag': 'KEY',
#       'value': 'ABCDEFGHIJKLMNabcdefghijklmnopqrstuvwxyz0123456789',
#       'start': 795,
#       'end': 845,
#       'context': 'ABCDEFGHIJKLMN0123456789",\n      accessTokenKey: "ABCDEFGHIJKLMNabcdefghijklmnopqrstuvwxyz0123456789",\n      accessTokenSecret: "0123456789abcdefghijk'}],
#     'FN': [{'tag': 'KEY',
#       'value': '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN',
#       'start': 874,
#       'end': 924,
#       'context': 'pqrstuvwxyz0123456789",\n      accessTokenSecret: "0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMN",\n      user: "username",\n    },\n    publication:'},
#      {'tag': 'KEY',
#       'value': '0123456789abcdefghijklmno',
#       'start': 670,
#       'end': 695,
#       'context': '34567890987654321",\n    options: {\n      apiKey: "0123456789abcdefghijklmno",\n      apiKeySecret: "abcdefghijklmnopqrstuvwxyz'}],
#     'FP': []}}},
#  {'id': 35,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 36,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 37,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 38,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 39,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 40,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '146.110.60.20',
#       'start': 353,
#       'end': 366}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '146.110.60.20',
#       'start': 353,
#       'end': 366,
#       'context': 'erver_connection = ServerConnection(\n    "rajk", "146.110.60.20", 2222, "/var/www/rajkdjango2/bin/python"\n)\n\n\ndef'}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 41,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [],
#     'FP': [{'tag': 'KEY',
#       'value': '7555e8e24958cae4cfd197135950359b9fe8373d4862a03677f089d215119a3a',
#       'start': 6052,
#       'end': 6116}]}}},
#  {'id': 42,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 43,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 44,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 45,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [],
#     'FP': [{'tag': 'IP_ADDRESS', 'value': '1.2.10.1', 'start': 31, 'end': 39},
#      {'tag': 'IP_ADDRESS', 'value': '1.2.10.1', 'start': 2086, 'end': 2094}]},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 46,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 47,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 48,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [{'tag': 'KEY',
#       'value': '6595b64144ccf1df',
#       'start': 378,
#       'end': 394},
#      {'tag': 'KEY', 'value': '6595b64144ccf1df', 'start': 599, 'end': 615},
#      {'tag': 'KEY', 'value': '6595b64144ccf1df', 'start': 820, 'end': 836},
#      {'tag': 'KEY', 'value': '6595b64144ccf1df', 'start': 1022, 'end': 1038}],
#     'TP_ref': [{'tag': 'KEY',
#       'value': '6595b64144ccf1df',
#       'start': 1022,
#       'end': 1038,
#       'context': '.0.0.0\' processorArchitecture=\'*\' publicKeyToken=\'6595b64144ccf1df\' language=\'*\'\\"")\n#endif\n'},
#      {'tag': 'KEY',
#       'value': '6595b64144ccf1df',
#       'start': 378,
#       'end': 394,
#       'context': '.0.0\' processorArchitecture=\'x86\' publicKeyToken=\'6595b64144ccf1df\' language=\'*\'\\"")\n#elif defined _M_IA64\n#pragma c'},
#      {'tag': 'KEY',
#       'value': '6595b64144ccf1df',
#       'start': 599,
#       'end': 615,
#       'context': '0.0\' processorArchitecture=\'ia64\' publicKeyToken=\'6595b64144ccf1df\' language=\'*\'\\"")\n#elif defined _M_X64\n#pragma co'},
#      {'tag': 'KEY',
#       'value': '6595b64144ccf1df',
#       'start': 820,
#       'end': 836,
#       'context': '.0\' processorArchitecture=\'amd64\' publicKeyToken=\'6595b64144ccf1df\' language=\'*\'\\"")\n#else\n#pragma comment(linker, "'}],
#     'FN': [],
#     'FP': []}}},
#  {'id': 49,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'diego.sueiro@gmail.com',
#       'start': 40,
#       'end': 62}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'diego.sueiro@gmail.com',
#       'start': 40,
#       'end': 62,
#       'context': '/*\n * Copyright (c) 2018, Diego Sueiro <diego.sueiro@gmail.com>\n *\n * SPDX-License-Identifier: Apache-2.0\n */\n\n#'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 50,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 51,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '121.14.110.200',
#       'start': 430,
#       'end': 444}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '121.14.110.200',
#       'start': 430,
#       'end': 444,
#       'context': '=True, auto_retry=True)\n    if not TDXHQ.connect(\'121.14.110.200\', 443):\n        raise Exception("Can\'t connect.")'}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 52,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 53,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'imre.leber@worldonline.be',
#       'start': 877,
#       'end': 902}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'imre.leber@worldonline.be',
#       'start': 877,
#       'end': 902,
#       'context': 's, suggestions, or fixes please\r\n   email me at:  imre.leber@worldonline.be\r\n*/\r\n\r\n#include <stdlib.h>\r\n#include <string.h>\r\n'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 54,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'qiang.xue@gmail.com',
#       'start': 264,
#       'end': 283}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'qiang.xue@gmail.com',
#       'start': 264,
#       'end': 283,
#       'context': 'pplication asset bundle.\n *\n * @author Qiang Xue <qiang.xue@gmail.com>\n * @since 2.0\n */\nclass IndexAsset extends Asset'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 55,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 56,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 57,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 58,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 59,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'tim.schneider@northbridge-development.de',
#       'start': 91,
#       'end': 131},
#      {'tag': 'EMAIL',
#       'value': 'mail@northbridge-development.de',
#       'start': 295,
#       'end': 326}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'mail@northbridge-development.de',
#       'start': 295,
#       'end': 326,
#       'context': ', ]\n__maintainer__ = "Tim Schneider"\n__email__ = "mail@northbridge-development.de"\n__status__ = "Development"\n\nlogger = logging.get'},
#      {'tag': 'EMAIL',
#       'value': 'tim.schneider@northbridge-development.de',
#       'start': 91,
#       'end': 131,
#       'context': ' -*-\nimport logging\n\n__author__ = \'Tim Schneider <tim.schneider@northbridge-development.de>\'\n__copyright__ = "Copyright 2015, Northbridge De'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 60,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '224.250.0.1',
#       'start': 1588,
#       'end': 1599}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '224.250.0.1',
#       'start': 1588,
#       'end': 1599,
#       'context': '/  e.g. eth0;239.192.0.1:7500\n//       link-local;224.250.0.1,224.250.0.2;224.250.0.3:8000\n//       ;[fe80::1%e'}],
#     'FN': [{'tag': 'IP_ADDRESS',
#       'value': '224.250.0.2',
#       'start': 1600,
#       'end': 1611,
#       'context': ';239.192.0.1:7500\n//       link-local;224.250.0.1,224.250.0.2;224.250.0.3:8000\n//       ;[fe80::1%en0]:7500\nint'},
#      {'tag': 'IP_ADDRESS',
#       'value': '224.250.0.3:8000',
#       'start': 1612,
#       'end': 1628,
#       'context': ':7500\n//       link-local;224.250.0.1,224.250.0.2;224.250.0.3:8000\n//       ;[fe80::1%en0]:7500\nint zmq::pgm_socket_'},
#      {'tag': 'IP_ADDRESS',
#       'value': '239.192.0.1:7500',
#       'start': 1551,
#       'end': 1567,
#       'context': ' & multicast group decls>:<IP port>\n//  e.g. eth0;239.192.0.1:7500\n//       link-local;224.250.0.1,224.250.0.2;224.2'}],
#     'FP': [{'tag': 'IP_ADDRESS',
#       'value': '239.192.0.1',
#       'start': 1551,
#       'end': 1562},
#      {'tag': 'IP_ADDRESS',
#       'value': '224.250.0.3',
#       'start': 1612,
#       'end': 1623}]},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 61,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 62,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'intersight@cisco.com',
#       'start': 1716,
#       'end': 1736}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'intersight@cisco.com',
#       'start': 1716,
#       'end': 1736,
#       'context': 'enAPI document.\n\nAPI version: 1.0.9-4903\nContact: intersight@cisco.com\n*/\n\n// Code generated by OpenAPI Generator (https'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 63,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'thamelry@binf.ku.dk',
#       'start': 40,
#       'end': 59}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'thamelry@binf.ku.dk',
#       'start': 40,
#       'end': 59,
#       'context': '# Copyright (C) 2002, Thomas Hamelryck (thamelry@binf.ku.dk)\n#\n# This file is part of the Biopython distribut'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 64,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'roygeesa@gmail.com',
#       'start': 1136,
#       'end': 1154}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'roygeesa@gmail.com',
#       'start': 1136,
#       'end': 1154,
#       'context': '><i class="fa fa-envelope-o"></i> <a href="mailto:roygeesa@gmail.com">roygeesa@gmail.com</a> </p>\n                <ul '}],
#     'FN': [{'tag': 'EMAIL',
#       'value': 'roygeesa@gmail.com',
#       'start': 1156,
#       'end': 1174,
#       'context': 'elope-o"></i> <a href="mailto:roygeesa@gmail.com">roygeesa@gmail.com</a> </p>\n                <ul class="list-unstyled'}],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 65,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 66,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 67,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'zaneadix@gmail.com',
#       'start': 63,
#       'end': 81}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'zaneadix@gmail.com',
#       'start': 63,
#       'end': 81,
#       'context': 'n: crew\nname: Zane Adickes\ntitle: Producer\nemail: zaneadix@gmail.com\nimage: /static/me_icecream.jpg\n---\n'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 68,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 69,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 70,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 2415,
#       'end': 2428},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 6789,
#       'end': 6802},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 6881,
#       'end': 6894},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 6973,
#       'end': 6986},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 7065,
#       'end': 7078}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 2415,
#       'end': 2428,
#       'context': 'ttpCallBean2 = cougarManager2.getNewHttpCallBean("87.248.113.14");\n        cougarManager2 = cougarManager2;\n\n    '},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 6881,
#       'end': 6894,
#       'context': 'eration", "BadRequest"),new AccessLogRequirement("87.248.113.14", "/cougarBaseline/v2/enumOperation", "BadRequest'},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 6789,
#       'end': 6802,
#       'context': 'e(getTimeAsTimeStamp11, new AccessLogRequirement("87.248.113.14", "/cougarBaseline/v2/enumOperation", "BadRequest'},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 7065,
#       'end': 7078,
#       'context': 'eration", "BadRequest"),new AccessLogRequirement("87.248.113.14", "/cougarBaseline/v2/enumOperation", "BadRequest'},
#      {'tag': 'IP_ADDRESS',
#       'value': '87.248.113.14',
#       'start': 6973,
#       'end': 6986}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 71,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'stegu@itn.liu.se',
#       'start': 237,
#       'end': 253}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'stegu@itn.liu.se',
#       'start': 237,
#       'end': 253,
#       'context': 'm the implementation written by Stefan Gustavson (stegu@itn.liu.se)\nand modified to fit to Unreal Engine 4\n\n\n* This '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 72,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': '1910646@tongji.edu.cn',
#       'start': 77,
#       'end': 98}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': '1910646@tongji.edu.cn',
#       'start': 77,
#       'end': 98,
#       'context': '- coding: utf-8 -*-\n# author: Irving He \n# email: 1910646@tongji.edu.cn\n\nimport logging\nimport argparse\nimport os\nimport '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 73,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 74,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'gustavo.valiente@protonmail.com',
#       'start': 42,
#       'end': 73}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'gustavo.valiente@protonmail.com',
#       'start': 42,
#       'end': 73,
#       'context': "/*\n * Copyright (c) 2018 Gustavo Valiente gustavo.valiente@protonmail.com\n *\n * This software is provided 'as-is', without "}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 75,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'scortes3@umd.edu',
#       'start': 46,
#       'end': 62},
#      {'tag': 'EMAIL', 'value': 'sameer@umd.edu', 'start': 85, 'end': 99},
#      {'tag': 'EMAIL',
#       'value': 'pkabra@terpmail.umd.edu',
#       'start': 115,
#       'end': 138}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'sameer@umd.edu',
#       'start': 85,
#       'end': 99,
#       'context': 'on Cortes (scortes3@umd.edu), Sameer Pusegaonkar (sameer@umd.edu), Pooja Kabra (pkabra@terpmail.umd.edu)\n * @brief'},
#      {'tag': 'EMAIL',
#       'value': 'pkabra@terpmail.umd.edu',
#       'start': 115,
#       'end': 138,
#       'context': 'Sameer Pusegaonkar (sameer@umd.edu), Pooja Kabra (pkabra@terpmail.umd.edu)\n * @brief Main node that processes an input imag'},
#      {'tag': 'EMAIL',
#       'value': 'scortes3@umd.edu',
#       'start': 46,
#       'end': 62,
#       'context': '/**\n * @file main.cpp\n * @author Shon Cortes (scortes3@umd.edu), Sameer Pusegaonkar (sameer@umd.edu), Pooja Kabr'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 76,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'david.sehnal@gmail.com',
#       'start': 232,
#       'end': 254},
#      {'tag': 'EMAIL',
#       'value': 'alexander.rose@weirdbyte.de',
#       'start': 283,
#       'end': 310}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'david.sehnal@gmail.com',
#       'start': 232,
#       'end': 254,
#       'context': 'sehnal/DensityServer)\n *\n * @author David Sehnal <david.sehnal@gmail.com>\n * @author Alexander Rose <alexander.rose@weirdb'},
#      {'tag': 'EMAIL',
#       'value': 'alexander.rose@weirdbyte.de',
#       'start': 283,
#       'end': 310,
#       'context': "avid.sehnal@gmail.com>\n * @author Alexander Rose <alexander.rose@weirdbyte.de>\n */\n\nimport * as fs from 'fs';\nimport { configur"}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 77,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 78,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 79,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 80,
#   'details': {'EMAIL': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [],
#     'FP': [{'tag': 'EMAIL',
#       'value': 'dehalleux@pelikhan.com',
#       'start': 124,
#       'end': 146}]},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 81,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 82,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 83,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'babarczi@tmit.bme.hu',
#       'start': 90,
#       'end': 110}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'babarczi@tmit.bme.hu',
#       'start': 90,
#       'end': 110,
#       'context': '             Babarczi Peter\n \\author              babarczi@tmit.bme.hu\n \\date                2015 november\n*/\n\n#include '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 84,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 85,
#   'details': {'EMAIL': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [],
#     'FP': [{'tag': 'EMAIL',
#       'value': 'support@coinapi.io',
#       'start': 328,
#       'end': 346}]},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 86,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 87,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'ljvderijk@gmail.com',
#       'start': 718,
#       'end': 737}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'ljvderijk@gmail.com',
#       'start': 718,
#       'end': 737,
#       'context': 'odels.\n"""\n\n__authors__ = [\n  \'"Lennard de Rijk" <ljvderijk@gmail.com>\',\n]\n\n\nfrom google.appengine.ext import db\n\nfrom '}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 88,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 89,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 90,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'bigeasy@linutronix.de',
#       'start': 203,
#       'end': 224}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'bigeasy@linutronix.de',
#       'start': 203,
#       'end': 224,
#       'context': 'd driver model)\n *\n * (c) 2007 Sebastian Siewior <bigeasy@linutronix.de>\n *\n */\n\n#include <linux/usb.h>\n#include <linux/i'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 91,
#   'details': {'EMAIL': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [{'tag': 'EMAIL',
#       'value': 'discoiquuid',
#       'start': 286,
#       'end': 297,
#       'context': 'ES\ntopic-tags: developing\ncontent-type: reference\ndiscoiquuid: da3891d3-fa07-4c88-b4ac-077926b3a674\nexl-id: 01a'},
#      {'tag': 'EMAIL',
#       'value': 'aaron.mcdonald@mailinator.com',
#       'start': 2511,
#       'end': 2540,
#       'context': 'onents are there.\n\nIf you logout and re-login as `aaron.mcdonald@mailinator.com/password` and refresh the page, you will observe '}],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 92,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '192.168.1.1',
#       'start': 4401,
#       'end': 4412}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '192.168.1.1',
#       'start': 4401,
#       'end': 4412,
#       'context': '     0x0101a8c0,       # .word   0x0101a8c0 @ ip: 192.168.1.1\n              # <shell>:\n              0x00000000'}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 93,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [],
#     'FP': [{'tag': 'KEY',
#       'value': '37697547/e2e_keypoint_rcnn_R-50-FPN_1x',
#       'start': 6386,
#       'end': 6424}]}}},
#  {'id': 94,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '127.0.0.1',
#       'start': 279,
#       'end': 288},
#      {'tag': 'IP_ADDRESS', 'value': '127.0.0.1', 'start': 1089, 'end': 1098}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '127.0.0.1',
#       'start': 279,
#       'end': 288,
#       'context': 'lgsvl.Simulator(os.environ.get("SIMULATOR_HOST", "127.0.0.1"), 8181)\n\nlayer_mask = 0\nlayer_mask |= 1 << 0  # '},
#      {'tag': 'IP_ADDRESS',
#       'value': '127.0.0.1',
#       'start': 1089,
#       'end': 1098,
#       'context': 'ego.connect_bridge(os.environ.get("BRIDGE_HOST", "127.0.0.1"), 9090)\n\n\n#------- Stand vehicle -------#\n#set s'}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 95,
#   'details': {'EMAIL': {'TP_pred': [],
#     'TP_ref': [],
#     'FN': [],
#     'FP': [{'tag': 'EMAIL',
#       'value': 'otp@example.com',
#       'start': 203,
#       'end': 218}]},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
# ...
#     'FP': []}}},
#  {'id': 358,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 359,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'reece.heineke@gmail.com',
#       'start': 32,
#       'end': 55}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'reece.heineke@gmail.com',
#       'start': 32,
#       'end': 55,
#       'context': '// Copyright 2014 Reece Heineke<reece.heineke@gmail.com>\n#include "iem/session.hpp"\n\n#include <algorithm>'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 360,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'y.sumi@aist.go.jp',
#       'start': 142,
#       'end': 159}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'y.sumi@aist.go.jp',
#       'start': 142,
#       'end': 159,
#       'context': 'r obstacle measurment\n *\n * @author Yasushi SUMI <y.sumi@aist.go.jp>\n * \n * Copyright (C) 2021  AIST\n * Released unde'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 361,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'itcpe@pinterest.com',
#       'start': 127,
#       'end': 146}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'itcpe@pinterest.com',
#       'start': 127,
#       'end': 146,
#       'context': "helloit'\nmaintainer 'Pinterest'\nmaintainer_email 'itcpe@pinterest.com'\nlicense 'Apache-2.0'\ndescription 'Installs/Confi"}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 362,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'bootrax@rackspace.com',
#       'start': 3785,
#       'end': 3806}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'bootrax@rackspace.com',
#       'start': 3785,
#       'end': 3806}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 363,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 364,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 365,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [{'tag': 'KEY',
#       'value': '23fedee89bcadec0487bf990c2c714d1',
#       'start': 3116,
#       'end': 3148}],
#     'TP_ref': [{'tag': 'KEY',
#       'value': '23fedee89bcadec0487bf990c2c714d1',
#       'start': 3116,
#       'end': 3148}],
#     'FN': [],
#     'FP': []}}},
#  {'id': 366,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 367,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 368,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 369,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 370,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'support@twilio.com',
#       'start': 104,
#       'end': 122}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'support@twilio.com',
#       'start': 104,
#       'end': 122,
#       'context': 'o REST API.\n *\n * API version: 1.24.0\n * Contact: support@twilio.com\n */\n\n// Code generated by OpenAPI Generator (http'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 371,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 372,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'hudvin@gmail.com',
#       'start': 228,
#       'end': 244}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'hudvin@gmail.com',
#       'start': 228,
#       'end': 244,
#       'context': 'er.pdf)\n\n\n## Contacts\n* email: [hudvin@gmail.com](hudvin@gmail.com) or [vadym.bartko@protonmail.com](vadym.bartko@pr'}],
#     'FN': [{'tag': 'EMAIL',
#       'value': 'vadym.bartko@protonmail.com',
#       'start': 279,
#       'end': 306,
#       'context': 'udvin@gmail.com) or [vadym.bartko@protonmail.com](vadym.bartko@protonmail.com)\n\n* skype: hudvin\n\n\n## COMPUTER SKILLS AND COMPET'},
#      {'tag': 'EMAIL',
#       'value': 'hudvin@gmail.com',
#       'start': 210,
#       'end': 226,
#       'context': 'hon Backend Engineer.pdf)\n\n\n## Contacts\n* email: [hudvin@gmail.com](hudvin@gmail.com) or [vadym.bartko@protonmail.co'},
#      {'tag': 'EMAIL',
#       'value': 'vadym.bartko@protonmail.com',
#       'start': 250,
#       'end': 277,
#       'context': '* email: [hudvin@gmail.com](hudvin@gmail.com) or [vadym.bartko@protonmail.com](vadym.bartko@protonmail.com)\n\n* skype: hudvin\n\n\n'}],
#     'FP': [{'tag': 'EMAIL',
#       'value': '[vadym.bartko@protonmail.com](vadym.bartko',
#       'start': 249,
#       'end': 291}]},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 373,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 374,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'haojian.zhuang@linaro.org',
#       'start': 166,
#       'end': 191},
#      {'tag': 'EMAIL', 'value': 'li.xin@linaro.org', 'start': 207, 'end': 224}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'li.xin@linaro.org',
#       'start': 207,
#       'end': 224,
#       'context': ' Zhuang <haojian.zhuang@linaro.org>\n *\t   Xin Li <li.xin@linaro.org>\n *\n * This program is free software; you can red'},
#      {'tag': 'EMAIL',
#       'value': 'haojian.zhuang@linaro.org',
#       'start': 166,
#       'end': 191,
#       'context': '013 Linaro Limited.\n *\n * Author: Haojian Zhuang <haojian.zhuang@linaro.org>\n *\t   Xin Li <li.xin@linaro.org>\n *\n * This prog'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 375,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'mark.samman@gmail.com',
#       'start': 112,
#       'end': 133}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'mark.samman@gmail.com',
#       'start': 112,
#       'end': 133,
#       'context': 'rver emulator\n * Copyright (C) 2015  Mark Samman <mark.samman@gmail.com>\n *\n * This program is free software; you can red'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 376,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 377,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'ryanpaik@protonmail.com',
#       'start': 3540,
#       'end': 3563}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'ryanpaik@protonmail.com',
#       'start': 3540,
#       'end': 3563,
#       'context': 'ou would like access to my Gist please email me.\n\nryanpaik@protonmail.com\n\n\n\n\n\n-----\n\n**Bio:**\n\nCurrently a Sophomore at Un'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 378,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 379,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'pjna@naughter.com',
#       'start': 4535,
#       'end': 4552}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'pjna@naughter.com',
#       'start': 4535,
#       'end': 4552,
#       'context': '015 by PJ Naughter (Web: www.naughter.com, Email: pjna@naughter.com)\r\n\r\nAll rights reserved.\r\n\r\nCopyright / Usage Det'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 380,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'steveu@coppice.org',
#       'start': 162,
#       'end': 180}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'steveu@coppice.org',
#       'start': 162,
#       'end': 180,
#       'context': 'tone detection.\n *\n * Written by Steve Underwood <steveu@coppice.org>\n *\n * Copyright (C) 2003 Steve Underwood\n *\n * A'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 381,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'clifford@clifford.at',
#       'start': 85,
#       'end': 105}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'clifford@clifford.at',
#       'start': 85,
#       'end': 105,
#       'context': 's Suite\n *\n *  Copyright (C) 2012  Clifford Wolf <clifford@clifford.at>\n *\n *  Permission to use, copy, modify, and/or d'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 382,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 383,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 384,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 385,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'admin@bitrixsoft.com',
#       'start': 163,
#       'end': 183}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'admin@bitrixsoft.com',
#       'start': 163,
#       'end': 183,
#       'context': 'ix\t\t\t#\n# http://www.bitrixsoft.com\t\t\t\t\t#\n# mailto:admin@bitrixsoft.com\t\t\t\t#\n############################################'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 386,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 387,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 388,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 389,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [{'tag': 'IP_ADDRESS',
#       'value': '127.0.0.1',
#       'start': 1365,
#       'end': 1374}],
#     'TP_ref': [{'tag': 'IP_ADDRESS',
#       'value': '127.0.0.1',
#       'start': 1365,
#       'end': 1374,
#       'context': 'iron.copy()\n        current_env["MASTER_ADDR"] = "127.0.0.1"\n        current_env["MASTER_PORT"] = str(args.ma'}],
#     'FN': [],
#     'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 390,
#   'details': {'EMAIL': {'TP_pred': [{'tag': 'EMAIL',
#       'value': 'levlam@telegram.org',
#       'start': 32,
#       'end': 51},
#      {'tag': 'EMAIL', 'value': 'arseny30@gmail.com', 'start': 70, 'end': 88}],
#     'TP_ref': [{'tag': 'EMAIL',
#       'value': 'arseny30@gmail.com',
#       'start': 70,
#       'end': 88,
#       'context': 'ksei Levin (levlam@telegram.org), Arseny Smirnov (arseny30@gmail.com) 2014-2018\n//\n// Distributed under the Boost Soft'},
#      {'tag': 'EMAIL',
#       'value': 'levlam@telegram.org',
#       'start': 32,
#       'end': 51,
#       'context': '//\n// Copyright Aliaksei Levin (levlam@telegram.org), Arseny Smirnov (arseny30@gmail.com) 2014-2018\n/'}],
#     'FN': [],
#     'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 391,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 392,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 393,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 394,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 395,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 396,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 397,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 398,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}},
#  {'id': 399,
#   'details': {'EMAIL': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'IP_ADDRESS': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []},
#    'KEY': {'TP_pred': [], 'TP_ref': [], 'FN': [], 'FP': []}}}]
